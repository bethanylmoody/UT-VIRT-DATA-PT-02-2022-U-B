# %%
# Dependencies
import requests

url = "http://api.worldbank.org/v2/"
format = "json"

# Get country information in JSON format
countries_response = requests.get(f"{url}countries?format={format}").json()

# First element is general information, second is countries themselves
countries = countries_response[1]

# %%
print(f"{url}countries?format={format}")
# Out:
# http://api.worldbank.org/v2/countries?format=json

# %%
import pandas as pd
pd.DataFrame(countries_response[1])
# Out:
#                                           adminregion          capitalCity  \
# 0             {'id': '', 'iso2code': '', 'value': ''}           Oranjestad
# 1   {'id': 'SAS', 'iso2code': '8S', 'value': 'Sout...                Kabul
# 2             {'id': '', 'iso2code': '', 'value': ''}
# 3   {'id': 'SSA', 'iso2code': 'ZF', 'value': 'Sub-...               Luanda
# 4   {'id': 'ECA', 'iso2code': '7E', 'value': 'Euro...               Tirane
# 5             {'id': '', 'iso2code': '', 'value': ''}     Andorra la Vella
# 6             {'id': '', 'iso2code': '', 'value': ''}
# 7             {'id': '', 'iso2code': '', 'value': ''}
# 8             {'id': '', 'iso2code': '', 'value': ''}            Abu Dhabi
# 9             {'id': '', 'iso2code': '', 'value': ''}         Buenos Aires
# 10  {'id': 'ECA', 'iso2code': '7E', 'value': 'Euro...              Yerevan
# 11  {'id': 'EAP', 'iso2code': '4E', 'value': 'East...            Pago Pago
# 12            {'id': '', 'iso2code': '', 'value': ''}         Saint John's
# 13            {'id': '', 'iso2code': '', 'value': ''}             Canberra
# 14            {'id': '', 'iso2code': '', 'value': ''}               Vienna
# 15  {'id': 'ECA', 'iso2code': '7E', 'value': 'Euro...                 Baku
# 16  {'id': 'SSA', 'iso2code': 'ZF', 'value': 'Sub-...            Bujumbura
# 17            {'id': '', 'iso2code': '', 'value': ''}
# 18            {'id': '', 'iso2code': '', 'value': ''}
# 19            {'id': '', 'iso2code': '', 'value': ''}             Brussels
# 20  {'id': 'SSA', 'iso2code': 'ZF', 'value': 'Sub-...           Porto-Novo
# 21  {'id': 'SSA', 'iso2code': 'ZF', 'value': 'Sub-...          Ouagadougou
# 22  {'id': 'SAS', 'iso2code': '8S', 'value': 'Sout...                Dhaka
# 23  {'id': 'ECA', 'iso2code': '7E', 'value': 'Euro...                Sofia
# 24            {'id': '', 'iso2code': '', 'value': ''}
# 25            {'id': '', 'iso2code': '', 'value': ''}               Manama
# 26            {'id': '', 'iso2code': '', 'value': ''}               Nassau
# 27  {'id': 'ECA', 'iso2code': '7E', 'value': 'Euro...             Sarajevo
# 28            {'id': '', 'iso2code': '', 'value': ''}
# 29  {'id': 'ECA', 'iso2code': '7E', 'value': 'Euro...                Minsk
# 30  {'id': 'LAC', 'iso2code': 'XJ', 'value': 'Lati...             Belmopan
# 31            {'id': '', 'iso2code': '', 'value': ''}
# 32            {'id': '', 'iso2code': '', 'value': ''}             Hamilton
# 33  {'id': 'LAC', 'iso2code': 'XJ', 'value': 'Lati...               La Paz
# 34  {'id': 'LAC', 'iso2code': 'XJ', 'value': 'Lati...             Brasilia
# 35            {'id': '', 'iso2code': '', 'value': ''}           Bridgetown
# 36            {'id': '', 'iso2code': '', 'value': ''}  Bandar Seri Begawan
# 37            {'id': '', 'iso2code': '', 'value': ''}
# 38  {'id': 'SAS', 'iso2code': '8S', 'value': 'Sout...              Thimphu
# 39  {'id': 'SSA', 'iso2code': 'ZF', 'value': 'Sub-...             Gaborone
# 40            {'id': '', 'iso2code': '', 'value': ''}
# 41  {'id': 'SSA', 'iso2code': 'ZF', 'value': 'Sub-...               Bangui
# 42            {'id': '', 'iso2code': '', 'value': ''}               Ottawa
# 43            {'id': '', 'iso2code': '', 'value': ''}
# 44            {'id': '', 'iso2code': '', 'value': ''}
# 45            {'id': '', 'iso2code': '', 'value': ''}
# 46            {'id': '', 'iso2code': '', 'value': ''}                 Bern
# 47            {'id': '', 'iso2code': '', 'value': ''}
# 48            {'id': '', 'iso2code': '', 'value': ''}             Santiago
# 49  {'id': 'EAP', 'iso2code': '4E', 'value': 'East...              Beijing
#
#      id                                        incomeLevel iso2Code  latitude  \
# 0   ABW  {'id': 'HIC', 'iso2code': 'XD', 'value': 'High...       AW   12.5167
# 1   AFG  {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low ...       AF   34.5228
# 2   AFR  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...       A9
# 3   AGO  {'id': 'LMC', 'iso2code': 'XN', 'value': 'Lowe...       AO  -8.81155
# 4   ALB  {'id': 'UMC', 'iso2code': 'XT', 'value': 'Uppe...       AL   41.3317
# 5   AND  {'id': 'HIC', 'iso2code': 'XD', 'value': 'High...       AD   42.5075
# 6   ANR  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...       L5
# 7   ARB  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...       1A
# 8   ARE  {'id': 'HIC', 'iso2code': 'XD', 'value': 'High...       AE   24.4764
# 9   ARG  {'id': 'HIC', 'iso2code': 'XD', 'value': 'High...       AR  -34.6118
# 10  ARM  {'id': 'UMC', 'iso2code': 'XT', 'value': 'Uppe...       AM   40.1596
# 11  ASM  {'id': 'UMC', 'iso2code': 'XT', 'value': 'Uppe...       AS  -14.2846
# 12  ATG  {'id': 'HIC', 'iso2code': 'XD', 'value': 'High...       AG   17.1175
# 13  AUS  {'id': 'HIC', 'iso2code': 'XD', 'value': 'High...       AU   -35.282
# 14  AUT  {'id': 'HIC', 'iso2code': 'XD', 'value': 'High...       AT   48.2201
# 15  AZE  {'id': 'UMC', 'iso2code': 'XT', 'value': 'Uppe...       AZ   40.3834
# 16  BDI  {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low ...       BI   -3.3784
# 17  BEA  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...       B4
# 18  BEC  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...       B7
# 19  BEL  {'id': 'HIC', 'iso2code': 'XD', 'value': 'High...       BE   50.8371
# 20  BEN  {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low ...       BJ    6.4779
# 21  BFA  {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low ...       BF   12.3605
# 22  BGD  {'id': 'LMC', 'iso2code': 'XN', 'value': 'Lowe...       BD   23.7055
# 23  BGR  {'id': 'UMC', 'iso2code': 'XT', 'value': 'Uppe...       BG   42.7105
# 24  BHI  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...       B1
# 25  BHR  {'id': 'HIC', 'iso2code': 'XD', 'value': 'High...       BH   26.1921
# 26  BHS  {'id': 'HIC', 'iso2code': 'XD', 'value': 'High...       BS   25.0661
# 27  BIH  {'id': 'UMC', 'iso2code': 'XT', 'value': 'Uppe...       BA   43.8607
# 28  BLA  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...       B2
# 29  BLR  {'id': 'UMC', 'iso2code': 'XT', 'value': 'Uppe...       BY   53.9678
# 30  BLZ  {'id': 'UMC', 'iso2code': 'XT', 'value': 'Uppe...       BZ   17.2534
# 31  BMN  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...       B3
# 32  BMU  {'id': 'HIC', 'iso2code': 'XD', 'value': 'High...       BM   32.3293
# 33  BOL  {'id': 'LMC', 'iso2code': 'XN', 'value': 'Lowe...       BO  -13.9908
# 34  BRA  {'id': 'UMC', 'iso2code': 'XT', 'value': 'Uppe...       BR  -15.7801
# 35  BRB  {'id': 'HIC', 'iso2code': 'XD', 'value': 'High...       BB   13.0935
# 36  BRN  {'id': 'HIC', 'iso2code': 'XD', 'value': 'High...       BN   4.94199
# 37  BSS  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...       B6
# 38  BTN  {'id': 'LMC', 'iso2code': 'XN', 'value': 'Lowe...       BT   27.5768
# 39  BWA  {'id': 'UMC', 'iso2code': 'XT', 'value': 'Uppe...       BW  -24.6544
# 40  CAA  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...       C9
# 41  CAF  {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low ...       CF   5.63056
# 42  CAN  {'id': 'HIC', 'iso2code': 'XD', 'value': 'High...       CA   45.4215
# 43  CEA  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...       C4
# 44  CEB  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...       B8
# 45  CEU  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...       C5
# 46  CHE  {'id': 'HIC', 'iso2code': 'XD', 'value': 'High...       CH    46.948
# 47  CHI  {'id': 'HIC', 'iso2code': 'XD', 'value': 'High...       JG
# 48  CHL  {'id': 'HIC', 'iso2code': 'XD', 'value': 'High...       CL   -33.475
# 49  CHN  {'id': 'UMC', 'iso2code': 'XT', 'value': 'Uppe...       CN   40.0495
#
#                                           lendingType longitude  \
# 0   {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not ...  -70.0167
# 1     {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'}   69.1761
# 2   {'id': '', 'iso2code': '', 'value': 'Aggregates'}
# 3    {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}    13.242
# 4    {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}   19.8172
# 5   {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not ...    1.5218
# 6   {'id': '', 'iso2code': '', 'value': 'Aggregates'}
# 7   {'id': '', 'iso2code': '', 'value': 'Aggregates'}
# 8   {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not ...   54.3705
# 9    {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}  -58.4173
# 10   {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}    44.509
# 11  {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not ...  -170.691
# 12   {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}  -61.8456
# 13  {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not ...   149.129
# 14  {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not ...   16.3798
# 15   {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}   49.8932
# 16    {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'}   29.3639
# 17  {'id': '', 'iso2code': '', 'value': 'Aggregates'}
# 18  {'id': '', 'iso2code': '', 'value': 'Aggregates'}
# 19  {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not ...   4.36761
# 20    {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'}    2.6323
# 21    {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'}  -1.53395
# 22    {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'}   90.4113
# 23   {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}   23.3238
# 24  {'id': '', 'iso2code': '', 'value': 'Aggregates'}
# 25  {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not ...   50.5354
# 26  {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not ...   -77.339
# 27   {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}   18.4214
# 28  {'id': '', 'iso2code': '', 'value': 'Aggregates'}
# 29   {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}   27.5766
# 30   {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}  -88.7713
# 31  {'id': '', 'iso2code': '', 'value': 'Aggregates'}
# 32  {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not ...   -64.706
# 33   {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}  -66.1936
# 34   {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}  -47.9292
# 35  {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not ...  -59.6105
# 36  {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not ...   114.946
# 37  {'id': '', 'iso2code': '', 'value': 'Aggregates'}
# 38    {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'}   89.6177
# 39   {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}   25.9201
# 40  {'id': '', 'iso2code': '', 'value': 'Aggregates'}
# 41    {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'}   21.6407
# 42  {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not ...  -75.6919
# 43  {'id': '', 'iso2code': '', 'value': 'Aggregates'}
# 44  {'id': '', 'iso2code': '', 'value': 'Aggregates'}
# 45  {'id': '', 'iso2code': '', 'value': 'Aggregates'}
# 46  {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not ...   7.44821
# 47  {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not ...
# 48   {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}  -70.6475
# 49   {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}   116.286
#
#                                                  name  \
# 0                                               Aruba
# 1                                         Afghanistan
# 2                                              Africa
# 3                                              Angola
# 4                                             Albania
# 5                                             Andorra
# 6                                       Andean Region
# 7                                          Arab World
# 8                                United Arab Emirates
# 9                                           Argentina
# 10                                            Armenia
# 11                                     American Samoa
# 12                                Antigua and Barbuda
# 13                                          Australia
# 14                                            Austria
# 15                                         Azerbaijan
# 16                                            Burundi
# 17          East Asia & Pacific (IBRD-only countries)
# 18        Europe & Central Asia (IBRD-only countries)
# 19                                            Belgium
# 20                                              Benin
# 21                                       Burkina Faso
# 22                                         Bangladesh
# 23                                           Bulgaria
# 24           IBRD countries classified as high income
# 25                                            Bahrain
# 26                                       Bahamas, The
# 27                             Bosnia and Herzegovina
# 28  Latin America & the Caribbean (IBRD-only count...
# 29                                            Belarus
# 30                                             Belize
# 31   Middle East & North Africa (IBRD-only countries)
# 32                                            Bermuda
# 33                                            Bolivia
# 34                                             Brazil
# 35                                           Barbados
# 36                                  Brunei Darussalam
# 37           Sub-Saharan Africa (IBRD-only countries)
# 38                                             Bhutan
# 39                                           Botswana
# 40            Sub-Saharan Africa (IFC classification)
# 41                           Central African Republic
# 42                                             Canada
# 43     East Asia and the Pacific (IFC classification)
# 44                     Central Europe and the Baltics
# 45       Europe and Central Asia (IFC classification)
# 46                                        Switzerland
# 47                                    Channel Islands
# 48                                              Chile
# 49                                              China
#
#                                                region
# 0   {'id': 'LCN', 'iso2code': 'ZJ', 'value': 'Lati...
# 1   {'id': 'SAS', 'iso2code': '8S', 'value': 'Sout...
# 2   {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 3   {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-...
# 4   {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Euro...
# 5   {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Euro...
# 6   {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 7   {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 8   {'id': 'MEA', 'iso2code': 'ZQ', 'value': 'Midd...
# 9   {'id': 'LCN', 'iso2code': 'ZJ', 'value': 'Lati...
# 10  {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Euro...
# 11  {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East...
# 12  {'id': 'LCN', 'iso2code': 'ZJ', 'value': 'Lati...
# 13  {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East...
# 14  {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Euro...
# 15  {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Euro...
# 16  {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-...
# 17  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 18  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 19  {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Euro...
# 20  {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-...
# 21  {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-...
# 22  {'id': 'SAS', 'iso2code': '8S', 'value': 'Sout...
# 23  {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Euro...
# 24  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 25  {'id': 'MEA', 'iso2code': 'ZQ', 'value': 'Midd...
# 26  {'id': 'LCN', 'iso2code': 'ZJ', 'value': 'Lati...
# 27  {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Euro...
# 28  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 29  {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Euro...
# 30  {'id': 'LCN', 'iso2code': 'ZJ', 'value': 'Lati...
# 31  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 32  {'id': 'NAC', 'iso2code': 'XU', 'value': 'Nort...
# 33  {'id': 'LCN', 'iso2code': 'ZJ', 'value': 'Lati...
# 34  {'id': 'LCN', 'iso2code': 'ZJ', 'value': 'Lati...
# 35  {'id': 'LCN', 'iso2code': 'ZJ', 'value': 'Lati...
# 36  {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East...
# 37  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 38  {'id': 'SAS', 'iso2code': '8S', 'value': 'Sout...
# 39  {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-...
# 40  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 41  {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-...
# 42  {'id': 'NAC', 'iso2code': 'XU', 'value': 'Nort...
# 43  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 44  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 45  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 46  {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Euro...
# 47  {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Euro...
# 48  {'id': 'LCN', 'iso2code': 'ZJ', 'value': 'Lati...
# 49  {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East...

# %%
# Report the names
for country in countries:
    print(country["name"])
# Out:
# Aruba
# Afghanistan
# Africa
# Angola
# Albania
# Andorra
# Andean Region
# Arab World
# United Arab Emirates
# Argentina
# Armenia
# American Samoa
# Antigua and Barbuda
# Australia
# Austria
# Azerbaijan
# Burundi
# East Asia & Pacific (IBRD-only countries)
# Europe & Central Asia (IBRD-only countries)
# Belgium
# Benin
# Burkina Faso
# Bangladesh
# Bulgaria
# IBRD countries classified as high income
# Bahrain
# Bahamas, The
# Bosnia and Herzegovina
# Latin America & the Caribbean (IBRD-only countries)
# Belarus
# Belize
# Middle East & North Africa (IBRD-only countries)
# Bermuda
# Bolivia
# Brazil
# Barbados
# Brunei Darussalam
# Sub-Saharan Africa (IBRD-only countries)
# Bhutan
# Botswana
# Sub-Saharan Africa (IFC classification)
# Central African Republic
# Canada
# East Asia and the Pacific (IFC classification)
# Central Europe and the Baltics
# Europe and Central Asia (IFC classification)
# Switzerland
# Channel Islands
# Chile
# China
